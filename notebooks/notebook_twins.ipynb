# %% [markdown]
# # Twins Dataset Analysis
#
# Analyzing the Twins dataset using causal inference methods.

# %%
import sys
sys.path.append('..')

import numpy as np
import pandas as pd
from pathlib import Path
import warnings
warnings.filterwarnings('ignore')

RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)

# %%
from src.data_loader import download_twins
from src.dowhy_pipeline import run_full_pipeline

data_path = download_twins()
if data_path:
    data = pd.read_csv(data_path)
    print(f"Loaded {len(data)} rows")
else:
    from dowhy.datasets import twins_dataset
    data = twins_dataset()
    print(f"Loaded {len(data)} rows via DoWhy")

# %%
results = run_full_pipeline(
    dataset_name="twins",
    estimators=["ipw", "psm", "dr"],
    output_dir=Path("../results"),
    random_state=RANDOM_SEED
)

print(results.to_string())
